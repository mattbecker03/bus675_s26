# %% [markdown]
# # Lecture 1: Course Introduction
# ## BUS675 - Advanced Business Machine Learning
#
# <img alt="Welcome banner with 80s neon style graphics welcoming students to the course" src="../images/L01_course_title_80s.png" width="800" style="display:block;">
#
# *"First learn stand, then learn fly."* — Mr. Miyagi, *The Karate Kid (1985)*
#
# This course is about the theory of advanced machine learning techniques and practical methods of incorporating machine learning in analytics workflows. You already know the fundamentals — this semester we'll focus on the professional tools, practices, and architectures that actually get models deployed and maintained in the real world. There is a fair amount of "roll up your sleeves" in this course, but the plan is to keep everything fun and playful.

# %% [markdown]
# ## Today's Agenda
#
# Since this is our first class together, we're going to keep things light. No coding today! 🎉
#
# 1. **A bit about me** — Who is this person who will be guiding you through the semester?
# 2. **Around the room** — I want to get to know each of you!
# 3. **Course overview** — What we'll learn and why it matters
# 4. **Logistics** — Structure, grading, expectations, and tools
# 5. **Questions & discussion** — Your chance to ask anything

# %% [markdown]
# # 1.0 A Bit About Me
# <img alt="Movie scene from Indiana Jones with adventure explorer theme representing teaching philosophy" width="700" src="../images/L01_instructor.png" style="display:block;">
# <font size=2>"Professor" Dewey Finn teaching in <i>School of Rock (2003)</i>.</font>
#
# A few things about me:
# - **Professional background**: My PhD is in theoretical physics, but now I teach at a Business School (shh, don't out me). During PhD, spent a couple years at particle accelerators (CERN) [Half Life game is accurate], before moving to theory.
# - **Research**: These days, I study how things (ideas, behavior, info) spread and change as they pass through "us" (social networks, digital platforms, etc.)
# - **Why I teach this course**: This is my **fun** course (where I get to teach stuff I find interesting; many profs secretly have a "fun course")
# - **Hobbies**: Blues guitar; haunted houses, horror movies, video games
# - **Fun fact**: I have an unhealthy obsession with 1980s movies. You'll notice references to *Back to the Future*, *Ghostbusters*, *The Goonies*, *Indiana Jones*, *Die Hard*, and various Arnold Schwarzenegger films throughout the course materials. Consider yourself warned. 🎬
#
#
# Extra credit if you watch one of the movies I reference and talk to me about it!

# %% [markdown]
# # 2.0 Around the Room — Let's Meet Each Other!
#
# <img alt="Scene from The Breakfast Club showing diverse group of students sitting together" src="../images/L01_breakfast_club.png" width="700" style="display:block;">
# <font size=2> The gang meet in <i>The Breakfast Club (1985)</i>.</font>
#
#
# I assume you all know each other pretty well by now, but I'm the new guy in the room. I want to learn about each of you, and get a better sense of what you're passionate about, where you are, and where you're going.

# %% [markdown]
# ## 🎤 The Lightning Round
#
# When it's your turn, share the following:
#
# ### 1. **Name & Your "Walk-Up Song"**
# You know how baseball players have a song that plays when they walk up to bat? If you had a walk-up song that played every time you entered a room, what would it be?
#
# ### 2. **Career Aspirations — The "Five Years from Now" Question**
# But let's make it interesting: *If a movie were made about your career five years from now, what genre would it be and what would it be called?*
#
# For example:
# - *"The Data Whisperer"* — A thriller about a analytics team manager at a large firm who sees patterns no one else can
# - *"Pandas & Chill"* — A romantic comedy about an analytics consultant who finds love helping a small firm grapple with their data.
# - *"The Optimization"* — A sci-fi epic about a lone wolf data virtuoso at an NGO who saves the world with linear programming
#
# ### 3. **Programming Comfort Level — Pick Your Character**
#
# Which of these best describes your current programming/analytics comfort level?
#
# | Character | Description |
# |-----------|-------------|
# | 🆕 **Marty McFly (Just Arrived)** | "Wait, where am I? What year is it?" — New to coding, still finding your bearings |
# | 🔧 **Egon Spengler (Tinkerer)** | "If my calculations are correct..." — Can get things working, sometimes explosively |
# | 🎯 **Indiana Jones (Adventurer)** | "I'm making this up as I go" — Comfortable with the basics, learning by doing |
# | 💪 **John McClane (Battle-Tested)** | "Yippee-ki-yay" — Been through some tough projects, came out the other side |
# | 🤖 **The Terminator (Unstoppable)** | "I'll be back" — Highly proficient, coding is second nature |
#
# ### 4. **The Random Fun Fact**
# Tell us something about yourself that would surprise us. Weird hobbies? Hidden talents? Strange fears? Did you once meet a celebrity? Do you have an unusual pet? The weirder the better!

# %% [markdown]
# ## 🗣️ Group Discussion: Program Pulse Check
#
# <img alt="Scene of friends discussing the fallout in Scream" src="../images/L01_scream_discussion.png" width="600" style="display:block;">
# <font size=2>The group discusses the carnage in <i>Scream (1996)</i></font>
#
# Let's have an open and frank discussion as a group:
#
# ### **How's the program going so far?**
#
# I'm genuinely curious to hear your thoughts. This is a safe space — I'm asking because I want to understand your experience and context, not to report back to anyone!
#
# Some prompts to get us started:
# - **Highlights**: What's been the best part of the program so far? A class that surprised you? A skill you're proud of developing?
# - **Challenges**: What's been harder than expected? What do you wish you'd known earlier?
# - **Connections**: Have you made friends or professional connections that you didn't expect?
# - **The Vibe**: How would you describe the program culture in one word?

# %% [markdown]
# # 3.0 Course Overview
#
# <img alt="The Goonies examining their treasure map planning their adventure ahead" width="700" src="../images/L01_goonies_map.png" style="display:block;">
# <font size=2>One-Eyed Willy's treasure map in <i>The Goonies (1985)</i></font>
#
#
# ## What This Course Is About
#
# This isn't your first analytics rodeo. You've taken foundational courses, you know your way around data, and you can run a regression. **This course takes you to the next level.**
#
# We'll cover:
# - 🐍 **Advanced Python practices** — Writing code like a professional
# - 🔧 **Development tools** — Git, Docker, remote development
# - 🧠 **Deep learning fundamentals** — Neural networks, PyTorch, and practical applications
# - 🗣️ **AI and LLMs - Theory and Practice** — How AI and LLMs work and how to use them for analytics
# - 🚀 **Production and Workflow Integration** — Because a model alone doesn't help anyone
#
# By the end, you'll be able to build, deploy, and maintain machine learning systems — not just run models in a Jupyter notebook.

# %% [markdown]
# ## The Semester at a Glance
#
# Here's a tentative schedule of the course. I will modify this as we go, based on feedback and my sense of comfort with the pace:
#
# | | Topic |
# |-------|-------|
# | 1 | Class Intro |
# | 2 | Software Setup + Dev Tools |
# | 3 | Python Best Practices & Modern Patterns |
# | 4 | Object Oriented Programming |
# | 4 | Object Oriented Programming (continued) |
# | LAB | RPG Adventure Game |
# | LAB | RPG Adventure Game |
# | 5 | Data Science in Python - Efficient File Formats and Large Data Handling |
# | 6 | Data Science in Python - Time Series and Geospatial Analysis |
# | 7 | Docker Containers |
# | LAB | Containerized Inference API |
# | 8 | NN Theory |
# | 9 | Pytorch - Fundamentals |
# | 10 | Pytorch - NN Architectures |
# | 11 | Pytorch - Training and Inference |
# | 12 | Pytorch - Convolutional NNs |
# | LAB | LAB: Build/Train a CNN |
# | LAB | LAB: Build/Train a CNN |
# | 13 | Text Embeddings and Attention Layers |
# | 14 | Working with Huggingface Models |
# | 15 | How LLMs work |
# | 16 | Using LLMs in workflows 1 |
# | 17 | Using LLMs in workflows 2 |
# | LAB | Report generation with LLMs |
# | LAB | Report generation with LLMs |
# | 18 | Special topic: Using local LLMs - Ollama |
# | 19 | Special topic: Rapid webapp dev - Streamlit |
# | LAB | Human vs LLM vs local LLM vs embedding classifier |
# | LAB | Human vs LLM vs local LLM vs embedding classifier |

# %% [markdown]
# # 4.0 Logistics
#
# <img alt="Theo manages the logistics of bank vault hacking" width="700" src="../images/L01_theo_logistics.png" style="display:block;">
# <font size=2>Theo manages bank vault logistics in <i>Die Hard (1989)</i></font>
#
# ## Course Structure
#
# **Format**: Each class session includes:
# - 📖 Lecture content and demonstrations
# - 💻 Hands-on coding exercises
# - 🔬 Lab assignments
#
# **Outside of class**:
# - Reading/review of lecture notebooks
# - Out-of-class work on lab assignments, exercises
#
# *"If there's a steady paycheck in it, I'll believe anything you say."* — Winston Zeddemore, *Ghostbusters (1984)*
#
# Translation: Consistent effort throughout the semester pays off better than cramming!

# %% [markdown]
# ## Grading
#
# | Component | Weight | Notes |
# |-----------|--------|-------|
# | Labs | 40% | Hands-on projects, typically spanning multiple class sessions |
# | Exercises | 40% | Shorter assignments reinforcing lecture concepts |
# | Participation | 20% | Attendance, engagement, and in-class contributions |

# %% [markdown]
# ## Expectations
#
# ### What I Expect from You
#
# 🎯 **Show up** — Attendance matters. This isn't the kind of class you can just read the notes for.
#
# 🤝 **Participate** — Ask questions, share insights, help classmates. Learning is a team sport.
#
# ⏰ **Put in the time** — Expect to spend time outside of class. The hands-on practice is where the real learning happens.
#
# 🆘 **Ask for help** — Confused? Stuck? Let me know early. I'm here to help, not to watch you struggle silently.
#
# ### What You Can Expect from Me
#
# 📚 **Clear, practical content** — Everything we cover has a purpose for your career.
#
# 🚀 **Real-world focus** — We'll use tools and techniques that professionals actually use.
#
# 🎯 **Timely feedback** — You'll get feedback on your work in a reasonable timeframe.
#
# 🚪 **Availability** — Office hours, email, or by appointment. I'm accessible.

# %% [markdown]
# ## Required Software & Tools
#
# You'll need the following installed on your machine:
#
# | Tool | Purpose |
# |------|---------|
# | **Python 3.10+** | Our primary programming language |
# | **VS Code** | Our IDE of choice |
# | **Git** | Version control |
# | **Docker Desktop** | Containerization (we'll install this together in Lecture 2) |
# | **Github Education Account** | Set this up as it will give you free access to Github Copilot Pro |
# | **AI Accounts** | You'll need to setup your own accounts for AI usage |
#
# ### AI Assistants
#
# Yes, you can use AI assistants like Claude Code, ChatGPT and GitHub Copilot! In fact, I encourage it — these are tools that professionals use every day.
#
# **But here's the deal**:
# - Make it a deliberate choice: turn off autocomplete code in ipynb notebooks (this is a crutch that fills in for us before we have a chance to think!)
# - Use AI to *accelerate* your learning, not replace it
# - You must understand any code you submit
# - Be prepared to explain your solutions
#
# *"The future is not set. There is no fate but what we make for ourselves."* — John Connor (well, technically Kyle Reese), *The Terminator*
#
# In other words: AI is a tool. What you do with it is up to you.

# %% [markdown]
# # 5.0 Questions & Discussion
#
# <img alt="questions" src="../images/L01_arnie_confused.png"  width="400" style="display:block;">
#
# The floor is open! What questions do you have about:
# - The course content?
# - Logistics and expectations?
# - Anything else?
#
# *No question is too basic. If you're wondering about something, chances are someone else is too.*

# %% [markdown]
# # 🎬 That's a Wrap!
#
# <img alt="End credits scene from an 80s movie with sunset" src="../images/L01_indiana_sunset.png" width="700" style="display:block;">
# <font size=2>Riding off into the sunset in <i>Indiana Jones and the Last Crusade (1989)</i></font>
#
# Thank you for a great first class! A few reminders:
#
# - ✅ Make sure you have Python and VS Code installed before next class.
# - ✅ Set up a Github account and verify you are a student for Github Education
# - ✅ Keep an eye on your email for any updates
# - ✅ Get ready — next class we dive into Git, terminal commands, and remote development!
#
# *"Life moves pretty fast. If you don't stop and look around once in a while, you could miss it."* — Ferris Bueller
#
# See you next class! 🚀
